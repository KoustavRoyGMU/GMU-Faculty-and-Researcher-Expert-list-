# %%
import pandas as pd
import os
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import re
nltk.download()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Simon\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
os.getcwd()
# Out:
# 'C:\\Users\\munna'

# %%
os.chdir(r'C:\Users\munna\Desktop\Final Project\Sprint 3\DATA COMBINING\Work 1')

# %%
# reading two csv files
data1 = pd.read_csv('merge.csv')
data2 = pd.read_csv('LinkedIn_Final.csv')

# %%
data2['authors'].str.lower()
df1 = pd.DataFrame(data2, columns = ['authors'])

# %%
data2['authors'] = df1['authors'].str.lower()

# %%
data2
# Out:
#      Unnamed: 0           authors  \
# 0             0      brett hunter
# 1             1  david kepplinger
# 2             2     ilhan izmirli
# 3             3     ilhan izmirli
# 4             4     ilhan izmirli
# ..          ...               ...
# 492         492   itamara lochard
# 493         493   itamara lochard
# 494         494   itamara lochard
# 495         495     robert latiff
# 496         496     robert latiff
#
#                                                  Title  \
# 0                               Time In Flight Podcast
# 1    Analysis of energy intensity in manufacturing ...
# 2    Review of the Paper "Parsimonious graphs for t...
# 3    Review of the Paper "Quantum GestART: identify...
# 4    Review of the paper “Quasiperiodic Music” by D...
# ..                                                 ...
# 492  “The Economic / Corruption Element in Afghanis...
# 493  “The Information / Cyber Element in Afghanista...
# 494  “The Role of New Media and Technology in Terro...
# 495  Future Peace: Technology, Aggression, and the ...
# 496  Future War: Preparing for the New Global Battl...
#
#                                           Descriptions       Date  \
# 0    This Podcast looks at what Covid-19 has does t...  30-Oct-20
# 1                                                  NaN  15-Sep-13
# 2                                                  NaN   8-Mar-22
# 3                                                  NaN   9-Sep-21
# 4                                                  NaN  11-May-21
# ..                                                 ...        ...
# 492  Presented research / paper on the economic and...   1-May-13
# 493  Presented research / paper on the information ...   1-May-13
# 494  Presented research / paper on there of new med...   1-May-13
# 495                                                NaN   1-Mar-22
# 496                                                NaN   1-Sep-17
#
#                                                  About  \
# 0                                                  NaN
# 1                                                  NaN
# 2       Director of Undergraduate StudiesDirector o...
# 3       Director of Undergraduate StudiesDirector o...
# 4       Director of Undergraduate StudiesDirector o...
# ..                                                 ...
# 492     Dr Itamara Lochard is a Professor and Direc...
# 493     Dr Itamara Lochard is a Professor and Direc...
# 494     Dr Itamara Lochard is a Professor and Direc...
# 495     Specialties: Technology and Management Cons...
# 496     Specialties: Technology and Management Cons...
#
#                                                   Link
# 0    https://www.linkedin.com/in/hunterbevis?miniPr...
# 1    https://www.linkedin.com/in/dakep?miniProfileU...
# 2    https://www.linkedin.com/in/ilhan-izmirli-150b...
# 3    https://www.linkedin.com/in/ilhan-izmirli-150b...
# 4    https://www.linkedin.com/in/ilhan-izmirli-150b...
# ..                                                 ...
# 492  https://www.linkedin.com/in/itamara?miniProfil...
# 493  https://www.linkedin.com/in/itamara?miniProfil...
# 494  https://www.linkedin.com/in/itamara?miniProfil...
# 495  https://www.linkedin.com/in/robert-latiff-4755...
# 496  https://www.linkedin.com/in/robert-latiff-4755...
#
# [497 rows x 7 columns]

# %%
data3 = pd.read_csv('LinkedIn_Final.csv')

# %%
data3['Descriptions'] = data3['Descriptions'].str.lower()# Converting Uppercase letters to Lower case
data3['About'] = data3['About'].str.lower()
data3['Descriptions'] = data3['Descriptions'].str.replace('\W', ' ', regex=True)# Removing special characters
data3['Descriptions'] = data3['Descriptions'].str.replace('-', ' ')
data3['authors'] = data3['authors'].str.lower()

# %%
data3
# Out:
#      Unnamed: 0           authors  \
# 0             0      brett hunter
# 1             1  david kepplinger
# 2             2     ilhan izmirli
# 3             3     ilhan izmirli
# 4             4     ilhan izmirli
# ..          ...               ...
# 492         492   itamara lochard
# 493         493   itamara lochard
# 494         494   itamara lochard
# 495         495     robert latiff
# 496         496     robert latiff
#
#                                                  Title  \
# 0                               Time In Flight Podcast
# 1    Analysis of energy intensity in manufacturing ...
# 2    Review of the Paper "Parsimonious graphs for t...
# 3    Review of the Paper "Quantum GestART: identify...
# 4    Review of the paper “Quasiperiodic Music” by D...
# ..                                                 ...
# 492  “The Economic / Corruption Element in Afghanis...
# 493  “The Information / Cyber Element in Afghanista...
# 494  “The Role of New Media and Technology in Terro...
# 495  Future Peace: Technology, Aggression, and the ...
# 496  Future War: Preparing for the New Global Battl...
#
#                                           Descriptions       Date  \
# 0    this podcast looks at what covid 19 has does t...  30-Oct-20
# 1                                                  NaN  15-Sep-13
# 2                                                  NaN   8-Mar-22
# 3                                                  NaN   9-Sep-21
# 4                                                  NaN  11-May-21
# ..                                                 ...        ...
# 492  presented research   paper on the economic and...   1-May-13
# 493  presented research   paper on the information ...   1-May-13
# 494  presented research   paper on there of new med...   1-May-13
# 495                                                NaN   1-Mar-22
# 496                                                NaN   1-Sep-17
#
#                                                  About  \
# 0                                                  NaN
# 1                                                  NaN
# 2       director of undergraduate studiesdirector o...
# 3       director of undergraduate studiesdirector o...
# 4       director of undergraduate studiesdirector o...
# ..                                                 ...
# 492     dr itamara lochard is a professor and direc...
# 493     dr itamara lochard is a professor and direc...
# 494     dr itamara lochard is a professor and direc...
# 495     specialties: technology and management cons...
# 496     specialties: technology and management cons...
#
#                                                   Link
# 0    https://www.linkedin.com/in/hunterbevis?miniPr...
# 1    https://www.linkedin.com/in/dakep?miniProfileU...
# 2    https://www.linkedin.com/in/ilhan-izmirli-150b...
# 3    https://www.linkedin.com/in/ilhan-izmirli-150b...
# 4    https://www.linkedin.com/in/ilhan-izmirli-150b...
# ..                                                 ...
# 492  https://www.linkedin.com/in/itamara?miniProfil...
# 493  https://www.linkedin.com/in/itamara?miniProfil...
# 494  https://www.linkedin.com/in/itamara?miniProfil...
# 495  https://www.linkedin.com/in/robert-latiff-4755...
# 496  https://www.linkedin.com/in/robert-latiff-4755...
#
# [497 rows x 7 columns]

# %%
new_stopwords = ["A", "from", "In", "This", "We","-"] # removing Stop Words
stpwrd = nltk.corpus.stopwords.words('english')
stpwrd.extend(new_stopwords)

# %%
stop = stopwords.words('english') #Removing Stopwords

df2 = data3
data3.columns = ["Unnamed: 0","authors","Title","Descriptions","Date","About","Link"]

data3["Title"] = data3["Title"].apply(lambda x: ' '.join([word for word in x.split() if word not in (stpwrd)]))
data3['Descriptions'] = data3['Descriptions'].apply(lambda x: ' '.join([word for word in str(x).split() if word not in (stpwrd)]))
data3['About'] = data3['About'].apply(lambda x: ' '.join([word for word in str(x).split() if word not in (stpwrd)]))

print(data3)
# Out:
#      Unnamed: 0           authors  \
# 0             0      brett hunter
# 1             1  david kepplinger
# 2             2     ilhan izmirli
# 3             3     ilhan izmirli
# 4             4     ilhan izmirli
# ..          ...               ...
# 492         492   itamara lochard
# 493         493   itamara lochard
# 494         494   itamara lochard
# 495         495     robert latiff
# 496         496     robert latiff
#
#                                                  Title  \
# 0                                  Time Flight Podcast
# 1    Analysis energy intensity manufacturing indust...
# 2    Review Paper "Parsimonious graphs common trich...
# 3    Review Paper "Quantum GestART: identifying app...
# 4    Review paper “Quasiperiodic Music” Darren C. Ong.
# ..                                                 ...
# 492  “The Economic / Corruption Element Afghanistan...
# 493  “The Information / Cyber Element Afghanistan.”...
# 494  “The Role New Media Technology Terrorist Recru...
# 495     Future Peace: Technology, Aggression, Rush War
# 496       Future War: Preparing New Global Battlefield
#
#                                           Descriptions       Date  \
# 0    podcast looks covid 19 various aspects aviatio...  30-Oct-20
# 1                                                  nan  15-Sep-13
# 2                                                  nan   8-Mar-22
# 3                                                  nan   9-Sep-21
# 4                                                  nan  11-May-21
# ..                                                 ...        ...
# 492  presented research paper economic corruption e...   1-May-13
# 493  presented research paper information cyber ele...   1-May-13
# 494  presented research paper new media technology ...   1-May-13
# 495                                                nan   1-Mar-22
# 496                                                nan   1-Sep-17
#
#                                                  About  \
# 0                                                  nan
# 1                                                  nan
# 2    director undergraduate studiesdirector undergr...
# 3    director undergraduate studiesdirector undergr...
# 4    director undergraduate studiesdirector undergr...
# ..                                                 ...
# 492  dr itamara lochard professor director cyber po...
# 493  dr itamara lochard professor director cyber po...
# 494  dr itamara lochard professor director cyber po...
# 495  specialties: technology management consulting,...
# 496  specialties: technology management consulting,...
#
#                                                   Link
# 0    https://www.linkedin.com/in/hunterbevis?miniPr...
# 1    https://www.linkedin.com/in/dakep?miniProfileU...
# 2    https://www.linkedin.com/in/ilhan-izmirli-150b...
# 3    https://www.linkedin.com/in/ilhan-izmirli-150b...
# 4    https://www.linkedin.com/in/ilhan-izmirli-150b...
# ..                                                 ...
# 492  https://www.linkedin.com/in/itamara?miniProfil...
# 493  https://www.linkedin.com/in/itamara?miniProfil...
# 494  https://www.linkedin.com/in/itamara?miniProfil...
# 495  https://www.linkedin.com/in/robert-latiff-4755...
# 496  https://www.linkedin.com/in/robert-latiff-4755...
#
# [497 rows x 7 columns]

# %%
data3.drop('Unnamed: 0', inplace=True, axis=1) #Dropping Column

# %%
data3['Descriptions'] = data3['Descriptions'].map(lambda x: re.sub(r'\W+', ' ', x)) #Removing Special Characters
data3['Title'] = data3['Title'].map(lambda x: re.sub(r'\W+', ' ', x))
data3['authors'] = data3['authors'].map(lambda x: re.sub(r'\W+', ' ', x))
data3['About'] = data3['About'].str.replace('\W', ' ')
# Out:
# C:\Users\Simon\AppData\Local\Temp\ipykernel_12868\1743372155.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   data3['About'] = data3['About'].str.replace('\W', ' ')

# %%
data3
# Out:
#               authors                                              Title  \
# 0        brett hunter                                Time Flight Podcast
# 1    david kepplinger  Analysis energy intensity manufacturing indust...
# 2       ilhan izmirli  Review Paper Parsimonious graphs common tricho...
# 3       ilhan izmirli  Review Paper Quantum GestART identifying apply...
# 4       ilhan izmirli     Review paper Quasiperiodic Music Darren C Ong
# ..                ...                                                ...
# 492   itamara lochard   The Economic Corruption Element Afghanistan N...
# 493   itamara lochard   The Information Cyber Element Afghanistan NAT...
# 494   itamara lochard   The Role New Media Technology Terrorist Recru...
# 495     robert latiff        Future Peace Technology Aggression Rush War
# 496     robert latiff        Future War Preparing New Global Battlefield
#
#                                           Descriptions       Date  \
# 0    podcast looks covid 19 various aspects aviatio...  30-Oct-20
# 1                                                  nan  15-Sep-13
# 2                                                  nan   8-Mar-22
# 3                                                  nan   9-Sep-21
# 4                                                  nan  11-May-21
# ..                                                 ...        ...
# 492  presented research paper economic corruption e...   1-May-13
# 493  presented research paper information cyber ele...   1-May-13
# 494  presented research paper new media technology ...   1-May-13
# 495                                                nan   1-Mar-22
# 496                                                nan   1-Sep-17
#
#                                                  About  \
# 0                                                  nan
# 1                                                  nan
# 2    director undergraduate studiesdirector undergr...
# 3    director undergraduate studiesdirector undergr...
# 4    director undergraduate studiesdirector undergr...
# ..                                                 ...
# 492  dr itamara lochard professor director cyber po...
# 493  dr itamara lochard professor director cyber po...
# 494  dr itamara lochard professor director cyber po...
# 495  specialties  technology management consulting ...
# 496  specialties  technology management consulting ...
#
#                                                   Link
# 0    https://www.linkedin.com/in/hunterbevis?miniPr...
# 1    https://www.linkedin.com/in/dakep?miniProfileU...
# 2    https://www.linkedin.com/in/ilhan-izmirli-150b...
# 3    https://www.linkedin.com/in/ilhan-izmirli-150b...
# 4    https://www.linkedin.com/in/ilhan-izmirli-150b...
# ..                                                 ...
# 492  https://www.linkedin.com/in/itamara?miniProfil...
# 493  https://www.linkedin.com/in/itamara?miniProfil...
# 494  https://www.linkedin.com/in/itamara?miniProfil...
# 495  https://www.linkedin.com/in/robert-latiff-4755...
# 496  https://www.linkedin.com/in/robert-latiff-4755...
#
# [497 rows x 6 columns]

# %%
output5 = pd.merge(data1, data3, 
                   on='authors', 
                   how='inner')

# %%
output5
# Out:
#                                                   titles          authors  \
# 0      balancing multiple objectives conformation sam...  ahmed bin zaman
# 1      balancing multiple objectives conformation sam...  ahmed bin zaman
# 2      balancing multiple objectives conformation sam...  ahmed bin zaman
# 3      balancing multiple objectives conformation sam...  ahmed bin zaman
# 4      balancing multiple objectives conformation sam...  ahmed bin zaman
# ...                                                  ...              ...
# 16800  distributed algorithm achieving finitetime min...        xuan wang
# 16801  distributed algorithm achieving finitetime min...        xuan wang
# 16802  distributed algorithm achieving finitetime min...        xuan wang
# 16803  distributed algorithm achieving finitetime min...        xuan wang
# 16804  distributed algorithm achieving finitetime min...        xuan wang
#
#           date                                             source  \
# 0      2019/12  balancing multiple objectives conformation sam...
# 1      2019/12  balancing multiple objectives conformation sam...
# 2      2019/12  balancing multiple objectives conformation sam...
# 3      2019/12  balancing multiple objectives conformation sam...
# 4      2019/12  balancing multiple objectives conformation sam...
# ...        ...                                                ...
# 16800     2018  distributed algorithm achieving finitetime min...
# 16801     2018  distributed algorithm achieving finitetime min...
# 16802     2018  distributed algorithm achieving finitetime min...
# 16803     2018  distributed algorithm achieving finitetime min...
# 16804     2018  distributed algorithm achieving finitetime min...
#
#                                             descriptions  citations  \
# 0      computational approaches determination biologi...       24.0
# 1      computational approaches determination biologi...       24.0
# 2      computational approaches determination biologi...       24.0
# 3      computational approaches determination biologi...       24.0
# 4      computational approaches determination biologi...       24.0
# ...                                                  ...        ...
# 16800  paper proposes distributed algorithm multiagen...        NaN
# 16801  paper proposes distributed algorithm multiagen...        NaN
# 16802  paper proposes distributed algorithm multiagen...        NaN
# 16803  paper proposes distributed algorithm multiagen...        NaN
# 16804  paper proposes distributed algorithm multiagen...        NaN
#
#       Phone Number                                          Biography  \
# 0              NaN  ever tell story let say friends called zoo bad...
# 1              NaN  ever tell story let say friends called zoo bad...
# 2              NaN  ever tell story let say friends called zoo bad...
# 3              NaN  ever tell story let say friends called zoo bad...
# 4              NaN  ever tell story let say friends called zoo bad...
# ...            ...                                                ...
# 16800          NaN  xuan wang assistant professor department elect...
# 16801          NaN  xuan wang assistant professor department elect...
# 16802          NaN  xuan wang assistant professor department elect...
# 16803          NaN  xuan wang assistant professor department elect...
# 16804          NaN  xuan wang assistant professor department elect...
#
#       Research Interest                                            Degrees  \
# 0                   NaN  phd  computer science  george mason university...
# 1                   NaN  phd  computer science  george mason university...
# 2                   NaN  phd  computer science  george mason university...
# 3                   NaN  phd  computer science  george mason university...
# 4                   NaN  phd  computer science  george mason university...
# ...                 ...                                                ...
# 16800               NaN  phd  aeronautics and astronautics  purdue univ...
# 16801               NaN  phd  aeronautics and astronautics  purdue univ...
# 16802               NaN  phd  aeronautics and astronautics  purdue univ...
# 16803               NaN  phd  aeronautics and astronautics  purdue univ...
# 16804               NaN  phd  aeronautics and astronautics  purdue univ...
#
#                                Profile Link                   Email  \
# 0             https://cec.gmu.edu/node/6886  mailto;azaman6@gmu.edu
# 1             https://cec.gmu.edu/node/6886  mailto;azaman6@gmu.edu
# 2             https://cec.gmu.edu/node/6886  mailto;azaman6@gmu.edu
# 3             https://cec.gmu.edu/node/6886  mailto;azaman6@gmu.edu
# 4             https://cec.gmu.edu/node/6886  mailto;azaman6@gmu.edu
# ...                                     ...                     ...
# 16800  https://ece.gmu.edu/profiles/xwang64         xwang64@gmu.edu
# 16801  https://ece.gmu.edu/profiles/xwang64         xwang64@gmu.edu
# 16802  https://ece.gmu.edu/profiles/xwang64         xwang64@gmu.edu
# 16803  https://ece.gmu.edu/profiles/xwang64         xwang64@gmu.edu
# 16804  https://ece.gmu.edu/profiles/xwang64         xwang64@gmu.edu
#
#                                      Personal Link  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 16800  https://mason.gmu.edu/~xwang64/index.html\n
# 16801  https://mason.gmu.edu/~xwang64/index.html\n
# 16802  https://mason.gmu.edu/~xwang64/index.html\n
# 16803  https://mason.gmu.edu/~xwang64/index.html\n
# 16804  https://mason.gmu.edu/~xwang64/index.html\n
#
#                                            Article Title  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 16800  detecting voip floods using the hellinger dist...
# 16801  detecting voip floods using the hellinger dist...
# 16802  detecting voip floods using the hellinger dist...
# 16803  detecting voip floods using the hellinger dist...
# 16804  detecting voip floods using the hellinger dist...
#
#                               Subjects-Keywords-Abstract  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 16800  internet telephony  computer network protocols...
# 16801  internet telephony  computer network protocols...
# 16802  internet telephony  computer network protocols...
# 16803  internet telephony  computer network protocols...
# 16804  internet telephony  computer network protocols...
#
#                                                    Title  \
# 0      Guiding Protein Conformation Sampling Conforma...
# 1      Adaptive Stochastic Optimization Improve Prote...
# 2      Protein Decoy Generation via Adaptive Stochast...
# 3      Reducing Ensembles Protein Tertiary Structures...
# 4      Decoy Ensemble Reduction Template free Protein...
# ...                                                  ...
# 16800  Distributed Algorithm Conservation Principle A...
# 16801  Distributed Linear Equation Solver Least Squar...
# 16802  Further Discussions Distributed Algorithm Solv...
# 16803  Improvement Distributed Algorithm Solving Line...
# 16804  Online De ection Estimation X axis Beam Positi...
#
#                     Descriptions       Date  \
# 0      finalist best paper award  22-Mar-22
# 1                            nan   9-Dec-21
# 2                            nan  19-Dec-20
# 3                            nan   9-May-20
# 4                            nan   1-Sep-19
# ...                          ...        ...
# 16800                        nan   1-Jun-18
# 16801                        nan   1-Dec-17
# 16802                        nan   1-May-17
# 16803                        nan   1-Apr-17
# 16804                        nan   1-Jan-16
#
#                                                    About  \
# 0                                                    nan
# 1                                                    nan
# 2                                                    nan
# 3                                                    nan
# 4                                                    nan
# ...                                                  ...
# 16800  swarm robot coordination  human in the loop au...
# 16801  swarm robot coordination  human in the loop au...
# 16802  swarm robot coordination  human in the loop au...
# 16803  swarm robot coordination  human in the loop au...
# 16804  swarm robot coordination  human in the loop au...
#
#                                                     Link
# 0      https://www.linkedin.com/in/ahmed-bin-zaman?mi...
# 1      https://www.linkedin.com/in/ahmed-bin-zaman?mi...
# 2      https://www.linkedin.com/in/ahmed-bin-zaman?mi...
# 3      https://www.linkedin.com/in/ahmed-bin-zaman?mi...
# 4      https://www.linkedin.com/in/ahmed-bin-zaman?mi...
# ...                                                  ...
# 16800  https://www.linkedin.com/in/xuan-wang-38819610...
# 16801  https://www.linkedin.com/in/xuan-wang-38819610...
# 16802  https://www.linkedin.com/in/xuan-wang-38819610...
# 16803  https://www.linkedin.com/in/xuan-wang-38819610...
# 16804  https://www.linkedin.com/in/xuan-wang-38819610...
#
# [16805 rows x 20 columns]

# %%
output5.titles.fillna('N/A',inplace=True)

# %%
output5.applymap(lambda x: np.nan if x == '?' else x)
# Out:
#                                                   titles          authors  \
# 0      balancing multiple objectives conformation sam...  ahmed bin zaman
# 1      balancing multiple objectives conformation sam...  ahmed bin zaman
# 2      balancing multiple objectives conformation sam...  ahmed bin zaman
# 3      balancing multiple objectives conformation sam...  ahmed bin zaman
# 4      balancing multiple objectives conformation sam...  ahmed bin zaman
# ...                                                  ...              ...
# 16800  distributed algorithm achieving finitetime min...        xuan wang
# 16801  distributed algorithm achieving finitetime min...        xuan wang
# 16802  distributed algorithm achieving finitetime min...        xuan wang
# 16803  distributed algorithm achieving finitetime min...        xuan wang
# 16804  distributed algorithm achieving finitetime min...        xuan wang
#
#           date                                             source  \
# 0      2019/12  balancing multiple objectives conformation sam...
# 1      2019/12  balancing multiple objectives conformation sam...
# 2      2019/12  balancing multiple objectives conformation sam...
# 3      2019/12  balancing multiple objectives conformation sam...
# 4      2019/12  balancing multiple objectives conformation sam...
# ...        ...                                                ...
# 16800     2018  distributed algorithm achieving finitetime min...
# 16801     2018  distributed algorithm achieving finitetime min...
# 16802     2018  distributed algorithm achieving finitetime min...
# 16803     2018  distributed algorithm achieving finitetime min...
# 16804     2018  distributed algorithm achieving finitetime min...
#
#                                             descriptions  citations  \
# 0      computational approaches determination biologi...       24.0
# 1      computational approaches determination biologi...       24.0
# 2      computational approaches determination biologi...       24.0
# 3      computational approaches determination biologi...       24.0
# 4      computational approaches determination biologi...       24.0
# ...                                                  ...        ...
# 16800  paper proposes distributed algorithm multiagen...        NaN
# 16801  paper proposes distributed algorithm multiagen...        NaN
# 16802  paper proposes distributed algorithm multiagen...        NaN
# 16803  paper proposes distributed algorithm multiagen...        NaN
# 16804  paper proposes distributed algorithm multiagen...        NaN
#
#       Phone Number                                          Biography  \
# 0              NaN  ever tell story let say friends called zoo bad...
# 1              NaN  ever tell story let say friends called zoo bad...
# 2              NaN  ever tell story let say friends called zoo bad...
# 3              NaN  ever tell story let say friends called zoo bad...
# 4              NaN  ever tell story let say friends called zoo bad...
# ...            ...                                                ...
# 16800          NaN  xuan wang assistant professor department elect...
# 16801          NaN  xuan wang assistant professor department elect...
# 16802          NaN  xuan wang assistant professor department elect...
# 16803          NaN  xuan wang assistant professor department elect...
# 16804          NaN  xuan wang assistant professor department elect...
#
#       Research Interest                                            Degrees  \
# 0                   NaN  phd  computer science  george mason university...
# 1                   NaN  phd  computer science  george mason university...
# 2                   NaN  phd  computer science  george mason university...
# 3                   NaN  phd  computer science  george mason university...
# 4                   NaN  phd  computer science  george mason university...
# ...                 ...                                                ...
# 16800               NaN  phd  aeronautics and astronautics  purdue univ...
# 16801               NaN  phd  aeronautics and astronautics  purdue univ...
# 16802               NaN  phd  aeronautics and astronautics  purdue univ...
# 16803               NaN  phd  aeronautics and astronautics  purdue univ...
# 16804               NaN  phd  aeronautics and astronautics  purdue univ...
#
#                                Profile Link                   Email  \
# 0             https://cec.gmu.edu/node/6886  mailto;azaman6@gmu.edu
# 1             https://cec.gmu.edu/node/6886  mailto;azaman6@gmu.edu
# 2             https://cec.gmu.edu/node/6886  mailto;azaman6@gmu.edu
# 3             https://cec.gmu.edu/node/6886  mailto;azaman6@gmu.edu
# 4             https://cec.gmu.edu/node/6886  mailto;azaman6@gmu.edu
# ...                                     ...                     ...
# 16800  https://ece.gmu.edu/profiles/xwang64         xwang64@gmu.edu
# 16801  https://ece.gmu.edu/profiles/xwang64         xwang64@gmu.edu
# 16802  https://ece.gmu.edu/profiles/xwang64         xwang64@gmu.edu
# 16803  https://ece.gmu.edu/profiles/xwang64         xwang64@gmu.edu
# 16804  https://ece.gmu.edu/profiles/xwang64         xwang64@gmu.edu
#
#                                      Personal Link  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 16800  https://mason.gmu.edu/~xwang64/index.html\n
# 16801  https://mason.gmu.edu/~xwang64/index.html\n
# 16802  https://mason.gmu.edu/~xwang64/index.html\n
# 16803  https://mason.gmu.edu/~xwang64/index.html\n
# 16804  https://mason.gmu.edu/~xwang64/index.html\n
#
#                                            Article Title  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 16800  detecting voip floods using the hellinger dist...
# 16801  detecting voip floods using the hellinger dist...
# 16802  detecting voip floods using the hellinger dist...
# 16803  detecting voip floods using the hellinger dist...
# 16804  detecting voip floods using the hellinger dist...
#
#                               Subjects-Keywords-Abstract  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 16800  internet telephony  computer network protocols...
# 16801  internet telephony  computer network protocols...
# 16802  internet telephony  computer network protocols...
# 16803  internet telephony  computer network protocols...
# 16804  internet telephony  computer network protocols...
#
#                                                    Title  \
# 0      Guiding Protein Conformation Sampling Conforma...
# 1      Adaptive Stochastic Optimization Improve Prote...
# 2      Protein Decoy Generation via Adaptive Stochast...
# 3      Reducing Ensembles Protein Tertiary Structures...
# 4      Decoy Ensemble Reduction Template free Protein...
# ...                                                  ...
# 16800  Distributed Algorithm Conservation Principle A...
# 16801  Distributed Linear Equation Solver Least Squar...
# 16802  Further Discussions Distributed Algorithm Solv...
# 16803  Improvement Distributed Algorithm Solving Line...
# 16804  Online De ection Estimation X axis Beam Positi...
#
#                     Descriptions       Date  \
# 0      finalist best paper award  22-Mar-22
# 1                            nan   9-Dec-21
# 2                            nan  19-Dec-20
# 3                            nan   9-May-20
# 4                            nan   1-Sep-19
# ...                          ...        ...
# 16800                        nan   1-Jun-18
# 16801                        nan   1-Dec-17
# 16802                        nan   1-May-17
# 16803                        nan   1-Apr-17
# 16804                        nan   1-Jan-16
#
#                                                    About  \
# 0                                                    nan
# 1                                                    nan
# 2                                                    nan
# 3                                                    nan
# 4                                                    nan
# ...                                                  ...
# 16800  swarm robot coordination  human in the loop au...
# 16801  swarm robot coordination  human in the loop au...
# 16802  swarm robot coordination  human in the loop au...
# 16803  swarm robot coordination  human in the loop au...
# 16804  swarm robot coordination  human in the loop au...
#
#                                                     Link
# 0      https://www.linkedin.com/in/ahmed-bin-zaman?mi...
# 1      https://www.linkedin.com/in/ahmed-bin-zaman?mi...
# 2      https://www.linkedin.com/in/ahmed-bin-zaman?mi...
# 3      https://www.linkedin.com/in/ahmed-bin-zaman?mi...
# 4      https://www.linkedin.com/in/ahmed-bin-zaman?mi...
# ...                                                  ...
# 16800  https://www.linkedin.com/in/xuan-wang-38819610...
# 16801  https://www.linkedin.com/in/xuan-wang-38819610...
# 16802  https://www.linkedin.com/in/xuan-wang-38819610...
# 16803  https://www.linkedin.com/in/xuan-wang-38819610...
# 16804  https://www.linkedin.com/in/xuan-wang-38819610...
#
# [16805 rows x 20 columns]

# %%
import numpy as np

# %%
data5 = output5.fillna('N/A')

# %%
data5
# Out:
#                                                   titles          authors  \
# 0      balancing multiple objectives conformation sam...  ahmed bin zaman
# 1      balancing multiple objectives conformation sam...  ahmed bin zaman
# 2      balancing multiple objectives conformation sam...  ahmed bin zaman
# 3      balancing multiple objectives conformation sam...  ahmed bin zaman
# 4      balancing multiple objectives conformation sam...  ahmed bin zaman
# ...                                                  ...              ...
# 16800  distributed algorithm achieving finitetime min...        xuan wang
# 16801  distributed algorithm achieving finitetime min...        xuan wang
# 16802  distributed algorithm achieving finitetime min...        xuan wang
# 16803  distributed algorithm achieving finitetime min...        xuan wang
# 16804  distributed algorithm achieving finitetime min...        xuan wang
#
#           date                                             source  \
# 0      2019/12  balancing multiple objectives conformation sam...
# 1      2019/12  balancing multiple objectives conformation sam...
# 2      2019/12  balancing multiple objectives conformation sam...
# 3      2019/12  balancing multiple objectives conformation sam...
# 4      2019/12  balancing multiple objectives conformation sam...
# ...        ...                                                ...
# 16800     2018  distributed algorithm achieving finitetime min...
# 16801     2018  distributed algorithm achieving finitetime min...
# 16802     2018  distributed algorithm achieving finitetime min...
# 16803     2018  distributed algorithm achieving finitetime min...
# 16804     2018  distributed algorithm achieving finitetime min...
#
#                                             descriptions citations  \
# 0      computational approaches determination biologi...      24.0
# 1      computational approaches determination biologi...      24.0
# 2      computational approaches determination biologi...      24.0
# 3      computational approaches determination biologi...      24.0
# 4      computational approaches determination biologi...      24.0
# ...                                                  ...       ...
# 16800  paper proposes distributed algorithm multiagen...       N/A
# 16801  paper proposes distributed algorithm multiagen...       N/A
# 16802  paper proposes distributed algorithm multiagen...       N/A
# 16803  paper proposes distributed algorithm multiagen...       N/A
# 16804  paper proposes distributed algorithm multiagen...       N/A
#
#       Phone Number                                          Biography  \
# 0              N/A  ever tell story let say friends called zoo bad...
# 1              N/A  ever tell story let say friends called zoo bad...
# 2              N/A  ever tell story let say friends called zoo bad...
# 3              N/A  ever tell story let say friends called zoo bad...
# 4              N/A  ever tell story let say friends called zoo bad...
# ...            ...                                                ...
# 16800          N/A  xuan wang assistant professor department elect...
# 16801          N/A  xuan wang assistant professor department elect...
# 16802          N/A  xuan wang assistant professor department elect...
# 16803          N/A  xuan wang assistant professor department elect...
# 16804          N/A  xuan wang assistant professor department elect...
#
#       Research Interest                                            Degrees  \
# 0                   N/A  phd  computer science  george mason university...
# 1                   N/A  phd  computer science  george mason university...
# 2                   N/A  phd  computer science  george mason university...
# 3                   N/A  phd  computer science  george mason university...
# 4                   N/A  phd  computer science  george mason university...
# ...                 ...                                                ...
# 16800               N/A  phd  aeronautics and astronautics  purdue univ...
# 16801               N/A  phd  aeronautics and astronautics  purdue univ...
# 16802               N/A  phd  aeronautics and astronautics  purdue univ...
# 16803               N/A  phd  aeronautics and astronautics  purdue univ...
# 16804               N/A  phd  aeronautics and astronautics  purdue univ...
#
#                                Profile Link                   Email  \
# 0             https://cec.gmu.edu/node/6886  mailto;azaman6@gmu.edu
# 1             https://cec.gmu.edu/node/6886  mailto;azaman6@gmu.edu
# 2             https://cec.gmu.edu/node/6886  mailto;azaman6@gmu.edu
# 3             https://cec.gmu.edu/node/6886  mailto;azaman6@gmu.edu
# 4             https://cec.gmu.edu/node/6886  mailto;azaman6@gmu.edu
# ...                                     ...                     ...
# 16800  https://ece.gmu.edu/profiles/xwang64         xwang64@gmu.edu
# 16801  https://ece.gmu.edu/profiles/xwang64         xwang64@gmu.edu
# 16802  https://ece.gmu.edu/profiles/xwang64         xwang64@gmu.edu
# 16803  https://ece.gmu.edu/profiles/xwang64         xwang64@gmu.edu
# 16804  https://ece.gmu.edu/profiles/xwang64         xwang64@gmu.edu
#
#                                      Personal Link  \
# 0                                              N/A
# 1                                              N/A
# 2                                              N/A
# 3                                              N/A
# 4                                              N/A
# ...                                            ...
# 16800  https://mason.gmu.edu/~xwang64/index.html\n
# 16801  https://mason.gmu.edu/~xwang64/index.html\n
# 16802  https://mason.gmu.edu/~xwang64/index.html\n
# 16803  https://mason.gmu.edu/~xwang64/index.html\n
# 16804  https://mason.gmu.edu/~xwang64/index.html\n
#
#                                            Article Title  \
# 0                                                    N/A
# 1                                                    N/A
# 2                                                    N/A
# 3                                                    N/A
# 4                                                    N/A
# ...                                                  ...
# 16800  detecting voip floods using the hellinger dist...
# 16801  detecting voip floods using the hellinger dist...
# 16802  detecting voip floods using the hellinger dist...
# 16803  detecting voip floods using the hellinger dist...
# 16804  detecting voip floods using the hellinger dist...
#
#                               Subjects-Keywords-Abstract  \
# 0                                                    N/A
# 1                                                    N/A
# 2                                                    N/A
# 3                                                    N/A
# 4                                                    N/A
# ...                                                  ...
# 16800  internet telephony  computer network protocols...
# 16801  internet telephony  computer network protocols...
# 16802  internet telephony  computer network protocols...
# 16803  internet telephony  computer network protocols...
# 16804  internet telephony  computer network protocols...
#
#                                                    Title  \
# 0      Guiding Protein Conformation Sampling Conforma...
# 1      Adaptive Stochastic Optimization Improve Prote...
# 2      Protein Decoy Generation via Adaptive Stochast...
# 3      Reducing Ensembles Protein Tertiary Structures...
# 4      Decoy Ensemble Reduction Template free Protein...
# ...                                                  ...
# 16800  Distributed Algorithm Conservation Principle A...
# 16801  Distributed Linear Equation Solver Least Squar...
# 16802  Further Discussions Distributed Algorithm Solv...
# 16803  Improvement Distributed Algorithm Solving Line...
# 16804  Online De ection Estimation X axis Beam Positi...
#
#                     Descriptions       Date  \
# 0      finalist best paper award  22-Mar-22
# 1                            nan   9-Dec-21
# 2                            nan  19-Dec-20
# 3                            nan   9-May-20
# 4                            nan   1-Sep-19
# ...                          ...        ...
# 16800                        nan   1-Jun-18
# 16801                        nan   1-Dec-17
# 16802                        nan   1-May-17
# 16803                        nan   1-Apr-17
# 16804                        nan   1-Jan-16
#
#                                                    About  \
# 0                                                    nan
# 1                                                    nan
# 2                                                    nan
# 3                                                    nan
# 4                                                    nan
# ...                                                  ...
# 16800  swarm robot coordination  human in the loop au...
# 16801  swarm robot coordination  human in the loop au...
# 16802  swarm robot coordination  human in the loop au...
# 16803  swarm robot coordination  human in the loop au...
# 16804  swarm robot coordination  human in the loop au...
#
#                                                     Link
# 0      https://www.linkedin.com/in/ahmed-bin-zaman?mi...
# 1      https://www.linkedin.com/in/ahmed-bin-zaman?mi...
# 2      https://www.linkedin.com/in/ahmed-bin-zaman?mi...
# 3      https://www.linkedin.com/in/ahmed-bin-zaman?mi...
# 4      https://www.linkedin.com/in/ahmed-bin-zaman?mi...
# ...                                                  ...
# 16800  https://www.linkedin.com/in/xuan-wang-38819610...
# 16801  https://www.linkedin.com/in/xuan-wang-38819610...
# 16802  https://www.linkedin.com/in/xuan-wang-38819610...
# 16803  https://www.linkedin.com/in/xuan-wang-38819610...
# 16804  https://www.linkedin.com/in/xuan-wang-38819610...
#
# [16805 rows x 20 columns]

# %%
data5.to_csv('Final_Consolidated Data1.csv')
