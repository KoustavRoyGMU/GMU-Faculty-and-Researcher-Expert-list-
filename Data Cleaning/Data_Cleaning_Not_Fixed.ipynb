# %%
import pandas as pd
import numpy as np
import os
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import re
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
# Load in neccessary Data.
LA = pd.read_csv('LinkdeIn_Abouts.csv' ,encoding_errors='ignore')
LP = pd.read_csv('LinkdeIn_Publications.csv' ,encoding_errors='ignore')
CEC = pd.read_csv('profiles_final_all.csv')
GS = pd.read_csv('merge.csv')
ASC = pd.read_csv('asc_consolidated_data.csv')

# %%
#Rename columns for LinkedIn Publications so column names are in common with CEC and Google Scholar files.
LP = LP.rename(columns={'Descriptions': 'descriptions','Title':'titles','Date':'date'})
LP
# Out:
#      Unnamed: 0              Name  \
# 0             0      Brett Hunter
# 1             0  David Kepplinger
# 2             0     Ilhan Izmirli
# 3             1     Ilhan Izmirli
# 4             2     Ilhan Izmirli
# ..          ...               ...
# 492          17   Itamara Lochard
# 493          18   Itamara Lochard
# 494          19   Itamara Lochard
# 495           0     Robert Latiff
# 496           1     Robert Latiff
#
#                                                 titles  \
# 0                               Time In Flight Podcast
# 1    Analysis of energy intensity in manufacturing ...
# 2    Review of the Paper "Parsimonious graphs for t...
# 3    Review of the Paper "Quantum GestART: identify...
# 4    Review of the paper “Quasiperiodic Music” by D...
# ..                                                 ...
# 492  “The Economic / Corruption Element in Afghanis...
# 493  “The Information / Cyber Element in Afghanista...
# 494  “The Role of New Media and Technology in Terro...
# 495  Future Peace: Technology, Aggression, and the ...
# 496  Future War: Preparing for the New Global Battl...
#
#                                           descriptions       date
# 0    This Podcast looks at what Covid-19 has does t...  30-Oct-20
# 1                                                  NaN  15-Sep-13
# 2                                                  NaN   8-Mar-22
# 3                                                  NaN   9-Sep-21
# 4                                                  NaN  11-May-21
# ..                                                 ...        ...
# 492  Presented research / paper on the economic and...   1-May-13
# 493  Presented research / paper on the information ...   1-May-13
# 494  Presented research / paper on there of new med...   1-May-13
# 495                                                NaN   1-Mar-22
# 496                                                NaN   1-Sep-17
#
# [497 rows x 5 columns]

# %%
#Rename columns for LinkedIn About sections so column names are in common with CEC and Google Scholar files.
LA = LA.rename(columns={'About': 'descriptions'})
LA
# Out:
#      Unnamed: 0                Name  \
# 0             0        Ariela Sofer
# 1             1       Arthur Pyster
# 2             2    Deborah Goodings
# 3             3  Abolfazl Safikhani
# 4             4        Brett Hunter
# ..          ...                 ...
# 195         195      Russell Hansen
# 196         196        Sandra Peake
# 197         197          Stone Bond
# 198         198       Traci Johnson
# 199         199       Robert Latiff
#
#                                           descriptions
# 0       Professor Ariela Sofer is Interim Divisiona...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 195     Russ is a Cyber Security Program Manager wi...
# 196                                                NaN
# 197      CISSP candidate ( boot camp completed)Spec...
# 198                                                NaN
# 199     Specialties: Technology and Management Cons...
#
# [200 rows x 3 columns]

# %%
#Rename author column so it is the same name as the CEC name column.
GS = GS.rename(columns={'authors': 'Name'})
GS
# Out:
#                                                   titles  \
# 0      joint structural break detection parameter est...
# 1      spatiotemporal modeling yellow taxi demands ne...
# 2      investigation range anxiety safety buffer batt...
# 3      cyclelength prediction actuated trafficsignal ...
# 4      nonstationary spatiotemporal modeling progress...
# ...                                                  ...
# 13278  detecting suspicious behavior surveillance images
# 13279  markerless identification dissimilarities gait...
# 13280  validating accuracy microsoft kinect depth inf...
# 13281  datadriven biomechanical analysis upper trapez...
# 13282                       workshop chairs introduction
#
#                                                     Name  \
# 0                        abolfazl safikhani, ali shojaie
# 1      abolfazl safikhani, camille kamga, sandeep mud...
# 2      quan yuan, wei hao, haotian su, guanwen bing, ...
# 3      bahman moghimi, abolfazl safikhani, camille ka...
# 4        yue bai, abolfazl safikhani, george michailidis
# ...                                                  ...
# 13278  carlotta domeniconi, zoran duric, maurizio fil...
# 13279  wallace lawson, nalini vishnoi, naomi lynn ger...
# 13280            sam gelman, nalini vishnoi, zoran duric
# 13281  qi wei, naomi lynn gerber, zoran duric, paul o...
# 13282  darius burschka, tat-jen cham, rama chelappa, ...
#
#                                                     date  \
# 0                                               2022/1/2
# 1                                               2020/7/1
# 2                                              2018/6/13
# 3                                               2018/3/1
# 4                                              2020/9/18
# ...                                                  ...
# 13278  we introduce a novel technique to detect anoma...
# 13279  gait analysis using computer vision techniques...
# 13280  conclusionskinect has greater error in depth d...
# 13281  chronic neck pain affects millions of american...
# 13282  computer vision as an implementation technolog...
#
#                                                   source  \
# 0      joint structural break detection parameter est...
# 1      spatiotemporal modeling yellow taxi demands ne...
# 2      investigation range anxiety safety buffer batt...
# 3      cyclelength prediction actuated trafficsignal ...
# 4      nonstationary spatiotemporal modeling progress...
# ...                                                  ...
# 13278  detecting suspicious behavior surveillance images
# 13279  markerless identification dissimilarities gait...
# 13280  validating accuracy microsoft kinect depth inf...
# 13281  datadriven biomechanical analysis upper trapez...
# 13282                       workshop chairs introduction
#
#                                             descriptions  citations  \
# 0      assuming stationarity unrealistic many time se...       56.0
# 1      spatiotemporal variation demand transportation...       40.0
# 2      drivers tend range anxiety compared driving tr...       40.0
# 3      urban transportation systems traffic signal ma...       31.0
# 4      fast transmission rate worldwide made virus im...       23.0
# ...                                                  ...        ...
# 13278  introduce novel technique detect anomalies ima...        NaN
# 13279  gait analysis using computer vision techniques...        NaN
# 13280                                        conclusions        NaN
# 13281  chronic neck pain affects millions americans a...        NaN
# 13282  computer vision implementation technology huma...        NaN
#
#       Phone Number Biography Research Interest Degrees Profile Link Email  \
# 0              NaN        na               NaN     NaN          NaN   NaN
# 1              NaN        na               NaN     NaN          NaN   NaN
# 2              NaN        na               NaN     NaN          NaN   NaN
# 3              NaN        na               NaN     NaN          NaN   NaN
# 4              NaN        na               NaN     NaN          NaN   NaN
# ...            ...       ...               ...     ...          ...   ...
# 13278          NaN        na               NaN     NaN          NaN   NaN
# 13279          NaN        na               NaN     NaN          NaN   NaN
# 13280          NaN        na               NaN     NaN          NaN   NaN
# 13281          NaN        na               NaN     NaN          NaN   NaN
# 13282          NaN        na               NaN     NaN          NaN   NaN
#
#       Personal Link Article Title Subjects-Keywords-Abstract
# 0               NaN           NaN                        NaN
# 1               NaN           NaN                        NaN
# 2               NaN           NaN                        NaN
# 3               NaN           NaN                        NaN
# 4               NaN           NaN                        NaN
# ...             ...           ...                        ...
# 13278           NaN           NaN                        NaN
# 13279           NaN           NaN                        NaN
# 13280           NaN           NaN                        NaN
# 13281           NaN           NaN                        NaN
# 13282           NaN           NaN                        NaN
#
# [13283 rows x 15 columns]

# %%
#take necessary columns from CEC and rename biography column so it is in common with the other files.
CEC = CEC[['Name', 'Biography']].copy()
CEC = CEC.rename(columns={'Biography': 'descriptions'})
CEC
# Out:
#                   Name                                       descriptions
# 0         Ariela Sofer   Ariela Sofer is interested in nonlinear progr...
# 1        Arthur Pyster  Throughout his career, Art Pyster has played l...
# 2     Deborah Goodings   Deborah Goodings is a professor and Associate...
# 3        Sanjeev Setia  Sanjeev Setia is a professor of computer scien...
# 4    Giacomo Francisci                                                NaN
# ..                 ...                                                ...
# 300         Stone Bond                                                NaN
# 301     Susan Schleigh                                                NaN
# 302      Traci Johnson                                                NaN
# 303      Joseph Kobsar                                                NaN
# 304      Robert Latiff                                                NaN
#
# [305 rows x 2 columns]

# %%
#Combine Subjects, Keywords, and Abstract columns and rename column names.
ASC = ASC.replace({np.nan: 'None'})
ASC['descriptions'] = ASC['Subjects']+ ';' + ASC['Keywords']+ ';' +ASC['Abstract']
ASC = ASC[['Article Title','Author', 'descriptions','Publication Date']].copy() 
ASC = ASC.rename(columns={'Article Title': 'titles','Author':'Name','Publication Date':'date'})

# %%
ASC
# Out:
#                                                 titles          Name  \
# 0    Rescuing Prometheus: Four Monumental Projects ...  Aditya Johri
# 1    Autonomous Visual Perception for Unmanned Surf...  Aditya Johri
# 2    Enhanced energy storage performance and therma...  Aditya Johri
# 3    High energy storage performances of Bi1−xSmxFe...  Aditya Johri
# 4    High-Performance Nonequilibrium InSb PIN Infra...  Aditya Johri
# ..                                                 ...           ...
# 740  Modeling Human-in-the-Loop Security Analysis a...      Yue Wang
# 741  Reasoning with advanced policy rules and its a...      Yue Wang
# 742  Removing Permissions in the Flexible Authoriza...      Yue Wang
# 743    Securing the ZigBee Protocol in the Smart Grid.      Yue Wang
# 744  SPUTERS: An Integrated Traffic Surveillance an...      Yue Wang
#
#                                           descriptions         date
# 0    HISTORY of technological innovations; NONFICTI...       16-Oct
# 1    AUTONOMOUS vehicles; COMPUTER vision; PATTERN ...       19-May
# 2    HEAT storage; RELAXOR ferroelectrics; THERMAL ...       21-Jun
# 3    LEAD-free ceramics; ENERGY storage; BISMUTH co...       19-Jul
# 4    PIN photodiodes; PHOTODETECTORS; CURRENT densi...       19-Mar
# ..                                                 ...          ...
# 740  MATHEMATICAL models of decision making; WORKFL...       14-Jan
# 741  ACCESS control; COMPUTER security; INFORMATION...         2004
# 742  COMPUTER security; SECURITY systems; DATA prot...        3-Sep
# 743  COMPUTER network protocols; CYBERTERRORISM; CO...       12-Apr
# 744  INFORMATION storage & retrieval systems; TRAFF...  Jan-Mar2005
#
# [745 rows x 4 columns]

# %%
#Concat data into one dataframe
data_concat = pd.concat([CEC,GS,ASC,LP,LA],ignore_index = True,sort=False)

# %%
#Replace empty cells or cells with messy data from scrapping with NAN
data_concat = data_concat.replace(r'^\s*$', np.nan, regex=True)
data_concat = data_concat.fillna('NNN/AAA')
data_concat = data_concat.apply(lambda x: x.astype(str).str.lower())
data_concat
# Out:
#                     Name                                       descriptions  \
# 0           ariela sofer   ariela sofer is interested in nonlinear progr...
# 1          arthur pyster  throughout his career, art pyster has played l...
# 2       deborah goodings   deborah goodings is a professor and associate...
# 3          sanjeev setia  sanjeev setia is a professor of computer scien...
# 4      giacomo francisci                                            nnn/aaa
# ...                  ...                                                ...
# 15025     russell hansen     russ is a cyber security program manager wi...
# 15026       sandra peake                                            nnn/aaa
# 15027         stone bond      cissp candidate ( boot camp completed)spec...
# 15028      traci johnson                                            nnn/aaa
# 15029      robert latiff     specialties: technology and management cons...
#
#         titles     date   source citations Phone Number Biography  \
# 0      nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
# 1      nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
# 2      nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
# 3      nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
# 4      nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
# ...        ...      ...      ...       ...          ...       ...
# 15025  nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
# 15026  nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
# 15027  nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
# 15028  nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
# 15029  nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
#
#       Research Interest  Degrees Profile Link    Email Personal Link  \
# 0               nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
# 1               nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
# 2               nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
# 3               nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
# 4               nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
# ...                 ...      ...          ...      ...           ...
# 15025           nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
# 15026           nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
# 15027           nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
# 15028           nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
# 15029           nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
#
#       Article Title Subjects-Keywords-Abstract Unnamed: 0
# 0           nnn/aaa                    nnn/aaa    nnn/aaa
# 1           nnn/aaa                    nnn/aaa    nnn/aaa
# 2           nnn/aaa                    nnn/aaa    nnn/aaa
# 3           nnn/aaa                    nnn/aaa    nnn/aaa
# 4           nnn/aaa                    nnn/aaa    nnn/aaa
# ...             ...                        ...        ...
# 15025       nnn/aaa                    nnn/aaa      195.0
# 15026       nnn/aaa                    nnn/aaa      196.0
# 15027       nnn/aaa                    nnn/aaa      197.0
# 15028       nnn/aaa                    nnn/aaa      198.0
# 15029       nnn/aaa                    nnn/aaa      199.0
#
# [15030 rows x 16 columns]

# %%
#Remove whitesapce, -, and " from desciptions
data_concat['descriptions'] = data_concat['descriptions'].str.replace('\W', ' ', regex=True)# Removing special characters
data_concat['descriptions'] = data_concat['descriptions'].str.replace('-', ' ')
data_concat['descriptions'] = data_concat['descriptions'].str.replace('"', '')
data_concat
# Out:
#                     Name                                       descriptions  \
# 0           ariela sofer   ariela sofer is interested in nonlinear progr...
# 1          arthur pyster  throughout his career  art pyster has played l...
# 2       deborah goodings   deborah goodings is a professor and associate...
# 3          sanjeev setia  sanjeev setia is a professor of computer scien...
# 4      giacomo francisci                                            nnn aaa
# ...                  ...                                                ...
# 15025     russell hansen     russ is a cyber security program manager wi...
# 15026       sandra peake                                            nnn aaa
# 15027         stone bond      cissp candidate   boot camp completed spec...
# 15028      traci johnson                                            nnn aaa
# 15029      robert latiff     specialties  technology and management cons...
#
#         titles     date   source citations Phone Number Biography  \
# 0      nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
# 1      nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
# 2      nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
# 3      nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
# 4      nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
# ...        ...      ...      ...       ...          ...       ...
# 15025  nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
# 15026  nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
# 15027  nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
# 15028  nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
# 15029  nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
#
#       Research Interest  Degrees Profile Link    Email Personal Link  \
# 0               nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
# 1               nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
# 2               nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
# 3               nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
# 4               nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
# ...                 ...      ...          ...      ...           ...
# 15025           nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
# 15026           nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
# 15027           nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
# 15028           nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
# 15029           nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
#
#       Article Title Subjects-Keywords-Abstract Unnamed: 0
# 0           nnn/aaa                    nnn/aaa    nnn/aaa
# 1           nnn/aaa                    nnn/aaa    nnn/aaa
# 2           nnn/aaa                    nnn/aaa    nnn/aaa
# 3           nnn/aaa                    nnn/aaa    nnn/aaa
# 4           nnn/aaa                    nnn/aaa    nnn/aaa
# ...             ...                        ...        ...
# 15025       nnn/aaa                    nnn/aaa      195.0
# 15026       nnn/aaa                    nnn/aaa      196.0
# 15027       nnn/aaa                    nnn/aaa      197.0
# 15028       nnn/aaa                    nnn/aaa      198.0
# 15029       nnn/aaa                    nnn/aaa      199.0
#
# [15030 rows x 16 columns]

# %%
#Add additional stop words to list
new_stopwords = ["A", "from", "In", "This", "We","-"] # removing Stop Words
stpwrd = nltk.corpus.stopwords.words('english')
stpwrd.extend(new_stopwords)

# %%
#Remove stop words from titles and descriptions
stop = stopwords.words('english') #Removing Stopwords

df2 = data_concat.copy()


df2["titles"] = df2["titles"].apply(lambda x: ' '.join([word for word in x.split() if word not in (stpwrd)]))
df2['descriptions'] = df2['descriptions'].apply(lambda x: ' '.join([word for word in str(x).split() if word not in (stpwrd)]))

df2
# Out:
#                     Name                                       descriptions  \
# 0           ariela sofer  ariela sofer interested nonlinear programming ...
# 1          arthur pyster  throughout career art pyster played leading te...
# 2       deborah goodings  deborah goodings professor associate dean grad...
# 3          sanjeev setia  sanjeev setia professor computer science inter...
# 4      giacomo francisci                                            nnn aaa
# ...                  ...                                                ...
# 15025     russell hansen  russ cyber security program manager demonstrat...
# 15026       sandra peake                                            nnn aaa
# 15027         stone bond  cissp candidate boot camp completed specialtie...
# 15028      traci johnson                                            nnn aaa
# 15029      robert latiff  specialties technology management consulting d...
#
#         titles     date   source citations Phone Number Biography  \
# 0      nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
# 1      nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
# 2      nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
# 3      nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
# 4      nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
# ...        ...      ...      ...       ...          ...       ...
# 15025  nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
# 15026  nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
# 15027  nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
# 15028  nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
# 15029  nnn/aaa  nnn/aaa  nnn/aaa   nnn/aaa      nnn/aaa   nnn/aaa
#
#       Research Interest  Degrees Profile Link    Email Personal Link  \
# 0               nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
# 1               nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
# 2               nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
# 3               nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
# 4               nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
# ...                 ...      ...          ...      ...           ...
# 15025           nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
# 15026           nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
# 15027           nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
# 15028           nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
# 15029           nnn/aaa  nnn/aaa      nnn/aaa  nnn/aaa       nnn/aaa
#
#       Article Title Subjects-Keywords-Abstract Unnamed: 0
# 0           nnn/aaa                    nnn/aaa    nnn/aaa
# 1           nnn/aaa                    nnn/aaa    nnn/aaa
# 2           nnn/aaa                    nnn/aaa    nnn/aaa
# 3           nnn/aaa                    nnn/aaa    nnn/aaa
# 4           nnn/aaa                    nnn/aaa    nnn/aaa
# ...             ...                        ...        ...
# 15025       nnn/aaa                    nnn/aaa      195.0
# 15026       nnn/aaa                    nnn/aaa      196.0
# 15027       nnn/aaa                    nnn/aaa      197.0
# 15028       nnn/aaa                    nnn/aaa      198.0
# 15029       nnn/aaa                    nnn/aaa      199.0
#
# [15030 rows x 16 columns]

# %%
#Removing Special Characters
df2['descriptions'] = df2['descriptions'].map(lambda x: re.sub(r'\W+', ' ', x)) 
df2['titles'] = df2['titles'].map(lambda x: re.sub(r'\W+', ' ', x))
df2['Name'] = df2['Name'].map(lambda x: re.sub(r'\W+', ' ', x))
df2 = df2.replace({'nnn/aaa': np.nan})
df2 = df2.replace({'nnn aaa': np.nan})
df2
# Out:
#                     Name                                       descriptions  \
# 0           ariela sofer  ariela sofer interested nonlinear programming ...
# 1          arthur pyster  throughout career art pyster played leading te...
# 2       deborah goodings  deborah goodings professor associate dean grad...
# 3          sanjeev setia  sanjeev setia professor computer science inter...
# 4      giacomo francisci                                                NaN
# ...                  ...                                                ...
# 15025     russell hansen  russ cyber security program manager demonstrat...
# 15026       sandra peake                                                NaN
# 15027         stone bond  cissp candidate boot camp completed specialtie...
# 15028      traci johnson                                                NaN
# 15029      robert latiff  specialties technology management consulting d...
#
#       titles date source citations Phone Number Biography Research Interest  \
# 0        NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 1        NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 2        NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 3        NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 4        NaN  NaN    NaN       NaN          NaN       NaN               NaN
# ...      ...  ...    ...       ...          ...       ...               ...
# 15025    NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 15026    NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 15027    NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 15028    NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 15029    NaN  NaN    NaN       NaN          NaN       NaN               NaN
#
#       Degrees Profile Link Email Personal Link Article Title  \
# 0         NaN          NaN   NaN           NaN           NaN
# 1         NaN          NaN   NaN           NaN           NaN
# 2         NaN          NaN   NaN           NaN           NaN
# 3         NaN          NaN   NaN           NaN           NaN
# 4         NaN          NaN   NaN           NaN           NaN
# ...       ...          ...   ...           ...           ...
# 15025     NaN          NaN   NaN           NaN           NaN
# 15026     NaN          NaN   NaN           NaN           NaN
# 15027     NaN          NaN   NaN           NaN           NaN
# 15028     NaN          NaN   NaN           NaN           NaN
# 15029     NaN          NaN   NaN           NaN           NaN
#
#       Subjects-Keywords-Abstract Unnamed: 0
# 0                            NaN        NaN
# 1                            NaN        NaN
# 2                            NaN        NaN
# 3                            NaN        NaN
# 4                            NaN        NaN
# ...                          ...        ...
# 15025                        NaN      195.0
# 15026                        NaN      196.0
# 15027                        NaN      197.0
# 15028                        NaN      198.0
# 15029                        NaN      199.0
#
# [15030 rows x 16 columns]

# %%
df2 = df2.fillna(value=np.nan)
df2
# Out:
#                     Name                                       descriptions  \
# 0           ariela sofer  ariela sofer interested nonlinear programming ...
# 1          arthur pyster  throughout career art pyster played leading te...
# 2       deborah goodings  deborah goodings professor associate dean grad...
# 3          sanjeev setia  sanjeev setia professor computer science inter...
# 4      giacomo francisci                                                NaN
# ...                  ...                                                ...
# 15025     russell hansen  russ cyber security program manager demonstrat...
# 15026       sandra peake                                                NaN
# 15027         stone bond  cissp candidate boot camp completed specialtie...
# 15028      traci johnson                                                NaN
# 15029      robert latiff  specialties technology management consulting d...
#
#       titles date source citations Phone Number Biography Research Interest  \
# 0        NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 1        NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 2        NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 3        NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 4        NaN  NaN    NaN       NaN          NaN       NaN               NaN
# ...      ...  ...    ...       ...          ...       ...               ...
# 15025    NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 15026    NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 15027    NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 15028    NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 15029    NaN  NaN    NaN       NaN          NaN       NaN               NaN
#
#       Degrees Profile Link Email Personal Link Article Title  \
# 0         NaN          NaN   NaN           NaN           NaN
# 1         NaN          NaN   NaN           NaN           NaN
# 2         NaN          NaN   NaN           NaN           NaN
# 3         NaN          NaN   NaN           NaN           NaN
# 4         NaN          NaN   NaN           NaN           NaN
# ...       ...          ...   ...           ...           ...
# 15025     NaN          NaN   NaN           NaN           NaN
# 15026     NaN          NaN   NaN           NaN           NaN
# 15027     NaN          NaN   NaN           NaN           NaN
# 15028     NaN          NaN   NaN           NaN           NaN
# 15029     NaN          NaN   NaN           NaN           NaN
#
#       Subjects-Keywords-Abstract Unnamed: 0
# 0                            NaN        NaN
# 1                            NaN        NaN
# 2                            NaN        NaN
# 3                            NaN        NaN
# 4                            NaN        NaN
# ...                          ...        ...
# 15025                        NaN      195.0
# 15026                        NaN      196.0
# 15027                        NaN      197.0
# 15028                        NaN      198.0
# 15029                        NaN      199.0
#
# [15030 rows x 16 columns]

# %%
#Remove few rows with many question marks
df2 = df2.applymap(lambda x: np.nan if x == '?' else x)
df2
# Out:
#                     Name                                       descriptions  \
# 0           ariela sofer  ariela sofer interested nonlinear programming ...
# 1          arthur pyster  throughout career art pyster played leading te...
# 2       deborah goodings  deborah goodings professor associate dean grad...
# 3          sanjeev setia  sanjeev setia professor computer science inter...
# 4      giacomo francisci                                                NaN
# ...                  ...                                                ...
# 15025     russell hansen  russ cyber security program manager demonstrat...
# 15026       sandra peake                                                NaN
# 15027         stone bond  cissp candidate boot camp completed specialtie...
# 15028      traci johnson                                                NaN
# 15029      robert latiff  specialties technology management consulting d...
#
#       titles date source citations Phone Number Biography Research Interest  \
# 0        NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 1        NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 2        NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 3        NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 4        NaN  NaN    NaN       NaN          NaN       NaN               NaN
# ...      ...  ...    ...       ...          ...       ...               ...
# 15025    NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 15026    NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 15027    NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 15028    NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 15029    NaN  NaN    NaN       NaN          NaN       NaN               NaN
#
#       Degrees Profile Link Email Personal Link Article Title  \
# 0         NaN          NaN   NaN           NaN           NaN
# 1         NaN          NaN   NaN           NaN           NaN
# 2         NaN          NaN   NaN           NaN           NaN
# 3         NaN          NaN   NaN           NaN           NaN
# 4         NaN          NaN   NaN           NaN           NaN
# ...       ...          ...   ...           ...           ...
# 15025     NaN          NaN   NaN           NaN           NaN
# 15026     NaN          NaN   NaN           NaN           NaN
# 15027     NaN          NaN   NaN           NaN           NaN
# 15028     NaN          NaN   NaN           NaN           NaN
# 15029     NaN          NaN   NaN           NaN           NaN
#
#       Subjects-Keywords-Abstract Unnamed: 0
# 0                            NaN        NaN
# 1                            NaN        NaN
# 2                            NaN        NaN
# 3                            NaN        NaN
# 4                            NaN        NaN
# ...                          ...        ...
# 15025                        NaN      195.0
# 15026                        NaN      196.0
# 15027                        NaN      197.0
# 15028                        NaN      198.0
# 15029                        NaN      199.0
#
# [15030 rows x 16 columns]

# %%
#Remove unncessary columns
df2 = df2.drop(columns=['Unnamed: 0'])
df2
# Out:
#                     Name                                       descriptions  \
# 0           ariela sofer  ariela sofer interested nonlinear programming ...
# 1          arthur pyster  throughout career art pyster played leading te...
# 2       deborah goodings  deborah goodings professor associate dean grad...
# 3          sanjeev setia  sanjeev setia professor computer science inter...
# 4      giacomo francisci                                                NaN
# ...                  ...                                                ...
# 15025     russell hansen  russ cyber security program manager demonstrat...
# 15026       sandra peake                                                NaN
# 15027         stone bond  cissp candidate boot camp completed specialtie...
# 15028      traci johnson                                                NaN
# 15029      robert latiff  specialties technology management consulting d...
#
#       titles date source citations Phone Number Biography Research Interest  \
# 0        NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 1        NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 2        NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 3        NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 4        NaN  NaN    NaN       NaN          NaN       NaN               NaN
# ...      ...  ...    ...       ...          ...       ...               ...
# 15025    NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 15026    NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 15027    NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 15028    NaN  NaN    NaN       NaN          NaN       NaN               NaN
# 15029    NaN  NaN    NaN       NaN          NaN       NaN               NaN
#
#       Degrees Profile Link Email Personal Link Article Title  \
# 0         NaN          NaN   NaN           NaN           NaN
# 1         NaN          NaN   NaN           NaN           NaN
# 2         NaN          NaN   NaN           NaN           NaN
# 3         NaN          NaN   NaN           NaN           NaN
# 4         NaN          NaN   NaN           NaN           NaN
# ...       ...          ...   ...           ...           ...
# 15025     NaN          NaN   NaN           NaN           NaN
# 15026     NaN          NaN   NaN           NaN           NaN
# 15027     NaN          NaN   NaN           NaN           NaN
# 15028     NaN          NaN   NaN           NaN           NaN
# 15029     NaN          NaN   NaN           NaN           NaN
#
#       Subjects-Keywords-Abstract
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 15025                        NaN
# 15026                        NaN
# 15027                        NaN
# 15028                        NaN
# 15029                        NaN
#
# [15030 rows x 15 columns]

# %%
#Adjust name difference from dataframe and CEC names
CEC = pd.read_csv('profiles_final_all.csv')
CEC = CEC.replace({np.nan: 'NNN/AAA'})
CEC = CEC.apply(lambda x: x.astype(str).str.lower())
CEC['Name'] = CEC['Name'].map(lambda x: re.sub(r'\W+', ' ', x))
CEC = CEC.replace({'nnn/aaa': 'N/A'})
CEC.to_csv('loadable_profiles_final_all.csv')
CEC
# Out:
#     Unnamed: 0               Name  \
# 0            0       ariela sofer
# 1            1      arthur pyster
# 2            2   deborah goodings
# 3            3      sanjeev setia
# 4            4  giacomo francisci
# ..         ...                ...
# 300        300         stone bond
# 301        301     susan schleigh
# 302        302      traci johnson
# 303        303      joseph kobsar
# 304        304      robert latiff
#
#                                                  Title  Phone Number  \
# 0    associate dean, administration and faculty aff...  703-993-1692
# 1    associate dean for research and professor, sys...           N/A
# 2    professor and associate dean, college of engin...  703-933-1504
# 3    professor\ncomputer science\nschool of computi...  703-993-4098
# 4                         postdoctoral research fellow           N/A
# ..                                                 ...           ...
# 300                        sr research program manager           N/A
# 301                           senior research engineer           N/A
# 302                                   research manager           N/A
# 303                               sr research engineer           N/A
# 304                                 research professor           N/A
#
#                                              Biography  \
# 0     ariela sofer is interested in nonlinear progr...
# 1    throughout his career, art pyster has played l...
# 2     deborah goodings is a professor and associate...
# 3    sanjeev setia is a professor of computer scien...
# 4                                                  N/A
# ..                                                 ...
# 300                                                N/A
# 301                                                N/A
# 302                                                N/A
# 303                                                N/A
# 304                                                N/A
#
#              Research Interest  \
# 0                optimization,
# 1                          N/A
# 2    geotechnical engineering,
# 3                          N/A
# 4                          N/A
# ..                         ...
# 300                        N/A
# 301                        N/A
# 302                        N/A
# 303                        N/A
# 304                        N/A
#
#                                                Degrees  \
# 0    phd, operations research,  george washington u...
# 1    phd, computer and information sciences,  the o...
# 2    phd, geotechnical engineering,  cambridge univ...
# 3                                                  N/A
# 4                                                  N/A
# ..                                                 ...
# 300                                                N/A
# 301                                                N/A
# 302                                                N/A
# 303                                                N/A
# 304                                                N/A
#
#                               Profile Link            Email  \
# 0      https://cec.gmu.edu/profiles/asofer              N/A
# 1     https://cec.gmu.edu/profiles/apyster  apyster@gmu.edu
# 2    https://cec.gmu.edu/profiles/goodings              N/A
# 3       https://cec.gmu.edu/profiles/setia    setia@gmu.edu
# 4                                      N/A              N/A
# ..                                     ...              ...
# 300                                    N/A              N/A
# 301                                    N/A              N/A
# 302                                    N/A              N/A
# 303                                    N/A              N/A
# 304                                    N/A              N/A
#
#                      Personal Link
# 0    http://mason.gmu.edu/~asofer/
# 1                              N/A
# 2                              N/A
# 3      http://cs.gmu.edu/~setia/\n
# 4                              N/A
# ..                             ...
# 300                            N/A
# 301                            N/A
# 302                            N/A
# 303                            N/A
# 304                            N/A
#
# [305 rows x 10 columns]

# %%
df2 = df2.replace('ã zlem uzuner', 'ozlem uzuner', regex=True)
df2 = df2.replace('ozlem uzuner', 'özlem uzuner', regex=True)

# %%
#Save file
df2.to_csv('Final_Data_For_NLP.csv')
