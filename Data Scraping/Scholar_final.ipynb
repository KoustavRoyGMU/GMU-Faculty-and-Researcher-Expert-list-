# %%
import requests
import lxml
import time
import random

import pandas as pd

# !pip uninstall selenium
# !pip uninstall chromedriver-binary
# %pip install selenium==4.2.0 --force-reinstall
# !pip install chromedriver-binary --force-reinstall
# !pip install webdriver-manager
# import selenium

from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

# %%
# driver = webdriver.Chrome(executable_path='C:\\chromedriver.exe')
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get('https://scholar.google.com/citations?view_op=view_org&hl=en&org=11304740246128990681')
# Out:
# C:\Users\Simon\AppData\Local\Temp\ipykernel_20540\2670034631.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
#scarping name list
names=[]
ProfileLinks=[]
topic = []
citations = []
titles = []

URL = 'https://scholar.google.com/citations?view_op=view_org&hl=en&org=11304740246128990681'

# ct = 0
while True:
    text = driver.page_source
    soup = BeautifulSoup(text, 'html.parser')
    people = soup.find_all('h3', {"class": "gs_ai_name"})
    for person in people:
        names.append(person.text)
        ProfileLinks.append('https://scholar.google.com/' + person.find_all('a')[0].get('href'))
    t = soup.find_all('div', {"class": "gs_ai_aff"})
    titles += [i.text for i in t]
    c = soup.find_all('div', {"class": "gs_ai_cby"})
    if c:
    #previous code       
        # citations += [int(i.text[9:]) for i in c]
        citations += [int(i.text[9:]) if i.text[9:].strip() else 0 for i in c]
    f = soup.find_all('div', {"class": "gs_ai_int"})
    for fields in f:
        field = fields.find_all('a', {"class": "gs_ai_one_int"})
        topics = ''
        for t in field:
            topics += t.text + ', '
        topics = topics[:-2]
        topic.append(topics)
    button = driver.find_element(By.XPATH,"//button[@class='gs_btnPR gs_in_ib gs_btn_half gs_btn_lsb gs_btn_srt gsc_pgn_pnx']")
    time.sleep(random.uniform(1.5, 2))
    button.click()
    time.sleep(3)
    NewURL = driver.current_url
    if NewURL == URL:
        break
    URL = NewURL
    driver.get(URL)
    
driver.close()

PeopleGMU = pd.DataFrame()
PeopleGMU['names'] = names
PeopleGMU['ProfileLinks'] = ProfileLinks
PeopleGMU['topics'] = topic
PeopleGMU['citations'] = citations
PeopleGMU['titles'] = titles

PeopleGMU
# Out:
#                    names                                       ProfileLinks  \
# 0           Lance Liotta  https://scholar.google.com//citations?hl=en&us...
# 1             Zoltan Acs  https://scholar.google.com//citations?hl=en&us...
# 2       Joseph A Maxwell  https://scholar.google.com//citations?hl=en&us...
# 3       Raja Parasuraman  https://scholar.google.com//citations?hl=en&us...
# 4      Emanuel Petricoin  https://scholar.google.com//citations?hl=en&us...
# ...                  ...                                                ...
# 1754    Breana Bayraktar  https://scholar.google.com//citations?hl=en&us...
# 1755  Fardin Ahsan Sakib  https://scholar.google.com//citations?hl=en&us...
# 1756         Sajed Jalil  https://scholar.google.com//citations?hl=en&us...
# 1757    AHM Rezaul Karim  https://scholar.google.com//citations?hl=en&us...
# 1758        Caleb Petitt  https://scholar.google.com//citations?hl=en&us...
#
#                                                  topics  citations  \
# 0                    cancer, bioengineering, proteomics     151910
# 1     Innovation, entrepreneurship, economic geograp...      72495
# 2     qualitative and mixed methods research, causat...      71863
# 3     Human Factors, Attention, Automation, Brain St...      51408
# 4     personalized medicine, cancer, cell sgnaling, ...      51254
# ...                                                 ...        ...
# 1754  faculty development, alternative grading pract...          0
# 1755  Natural Language Processing, Machine Learning,...          0
# 1756   Software Engineering, Human Computer Interaction          0
# 1757  Machine Learning, Cyber Security, Natural Lang...          0
# 1758                                          Economics          0
#
#                                                 titles
# 0                    Professor George Mason University
# 1                              George Mason University
# 2                              George Mason University
# 3     Professor of Psychology, George Mason University
# 4                              George Mason University
# ...                                                ...
# 1754    Educational developer, George Mason University
# 1755              PhD Student, George Mason University
# 1756            Ph.D. Student, George Mason University
# 1757              PhD Student, George Mason University
# 1758                           George Mason University
#
# [1759 rows x 5 columns]

# %% [markdown]
# Error occure logs
#
# 1) page 1671-1680 (https://scholar.google.com/citations?view_op=view_org&hl=en&org=11304740246128990681&after_author=PfYoAfz___8J&astart=1670)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15952\2403409559.py in <module>
#      20     c = soup.find_all('div', {"class": "gs_ai_cby"})
#      21     if c:
# ---> 22         citations += [int(i.text[9:]) for i in c]
#      23     f = soup.find_all('div', {"class": "gs_ai_int"})
#      24     for fields in f:
#
# ~\AppData\Local\Temp\ipykernel_15952\2403409559.py in <listcomp>(.0)
#      20     c = soup.find_all('div', {"class": "gs_ai_cby"})
#      21     if c:
# ---> 22         citations += [int(i.text[9:]) for i in c]
#      23     f = soup.find_all('div', {"class": "gs_ai_int"})
#      24     for fields in f:
#
# ValueError: invalid literal for int() with base 10: ''
#
# 2)

# %%
#  PeopleGMU.to_csv('PeopleGMU.csv', index=False)
#  print(PeopleGMU.iloc[1,1])
# Out:
# https://scholar.google.com//citations?hl=en&user=eupbxcwAAAAJ

# %%
# driver = webdriver.Chrome(executable_path='C:\\chromedriver.exe')
driver = webdriver.Chrome(ChromeDriverManager().install())
# driver.get(personURL)

## test personURL
# driver.get("https://scholar.google.com//citations?hl=en&user=iB-5P0EAAAAJ")
driver.get("https://scholar.google.com/citations?hl=en&user=t33F2BcAAAAJ")
#scraping publications
text = driver.page_source
soup = BeautifulSoup(text, 'html.parser')

objects = soup.find_all('tr', {"class": "gsc_a_tr"})

base = ['' for i in range(len(objects))]
pubs = pd.DataFrame()
pubs['titles'] = base
pubs['authors'] = base
pubs['date'] = base
pubs['source'] = base
pubs['descriptions'] = base
pubs['citations'] = base

for i, obj in enumerate(objects):
    pubs.loc[i, 'titles'] = obj.find_all('a')[0].text.replace('\xa0', ' ')
    time.sleep(random.uniform(0.75, 1.5))
    # driver.find_element_by_link_text(pubs.loc[i, 'titles']).click()
    driver.find_element("link text",pubs.loc[i, 'titles']).click()
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    p = soup.find_all('div', {"class": "gsc_oci_value"})
    pubs.loc[i, 'authors'] = soup.find_all('div', {"class": "gsc_oci_value"})[0].text
    pubs.loc[i, 'date'] = soup.find_all('div', {"class": "gsc_oci_value"})[1].text
    pubs.loc[i, 'source'] = soup.find_all('div', {"class": "gsc_oci_field"})[2].text + ' ' + soup.find_all('div', {"class": "gsc_oci_value"})[2].text
    if soup.find_all('div', {"class": "gsh_csp"}):
        pubs.loc[i, 'descriptions'] = soup.find_all('div', {"class": "gsh_csp"})[0].text
    elif soup.find_all('div', {"class": "gsh_small"}):
        pubs.loc[i, 'descriptions'] = soup.find_all('div', {"class": "gsh_small"})[0].text
    if soup.find_all('div', {"style": "margin-bottom:1em"}):
        pubs.loc[i, 'citations'] = soup.find_all('div', {"style": "margin-bottom:1em"})[0].text[9:]
    time.sleep(random.uniform(1, 2))
    driver.back()
pubs
# Out:
# C:\Users\Simon\AppData\Local\Temp\ipykernel_20540\4280523922.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
#                                                titles  \
# 0   MERS-CoV papain-like protease has deISGylating...
# 1   Structural basis for the ubiquitin-linkage spe...
# 2   Bacterial and viral identification and differe...
# 3   Assessing activity and inhibition of Middle Ea...
# 4   Cell-based antiviral screening against coronav...
# 5   Use of unamplified RNA/cDNA–hybrid nanopore se...
# 6   Pathosphere. org: pathogen detection and chara...
# 7   Comparative characterization of the Sindbis vi...
# 8   Assessing activity and inhibition of MERS-CoV ...
# 9   Gain-of-function research and the relevance to...
# 10  The planning, execution, and evaluation of a m...
# 11  Effectively communicating the uncertainties su...
# 12  Tracking a serial killer: Integrating phylogen...
# 13  440 Rosenzweig CN, Minot SS: Bacterial and vir...
# 14  When gain‐of‐function research is not “gain‐of...
# 15  Assessment of wearable technology for integrat...
# 16  Careers in virology: public health opportuniti...
# 17                                  Reply to Lipsitch
# 18  Coronavirus proteases as therapeutic targets: ...
#
#                                               authors        date  \
# 0   Anna M Mielech, Andy Kilianski, Yahira M Baez-...    2014/2/1
# 1   Kiira Ratia, Andrew Kilianski, Yahira M Baez-S...   2014/5/22
# 2   Andy Kilianski, Jamie L Haas, Elizabeth J Corr...   2015/12/1
# 3   Andy Kilianski, Anna M Mielech, Xufang Deng, S...   2013/11/1
# 4                       Andy Kilianski, Susan C Baker    2014/1/1
# 5   Andy Kilianski, Pierce A Roth, Alvin T Liem, J...      2016/8
# 6   Andy Kilianski, Patrick Carcel, Shijie Yao, Pi...     2015/12
# 7   Ryan Schuchman, Andy Kilianski, Amanda Piper, ...   2018/7/15
# 8   Andy Kilianski, Anna Mielech, Xufang Deng, Sus...   2013/8/28
# 9   Andy Kilianski, Jennifer B Nuzzo, Kayvon Modja...    2016/5/1
# 10  Andy Kilianski, Amy T O'Rourke, Crystal L Carl...    2014/3/1
# 11                   Andy Kilianski, Nicholas G Evans  2015/10/29
# 12  Ifeoma Ezeoke, Madeline R Galac, Ying Lin, Alv...  2018/11/28
# 13  A Kilianski, JL Haas, EJ Corriveau, AT Liem, K...        2015
# 14                    Andy Kilianski, Randall S Murch     2015/12
# 15  David L Hirschberg, Alan C Samuels, CN Rosenzw...    2016/5/1
# 16                                     Andy Kilianski   2014/7/15
# 17  Andy Kilianski, Jennifer B Nuzzo, Kayvon Modja...  2016/10/15
# 18                                   Andrew Kilianski      2014/8
#
#                                                source  \
# 0                                    Journal Virology
# 1                              Journal PLoS pathogens
# 2                                 Journal Gigascience
# 3                         Journal Journal of virology
# 4                           Source Antiviral research
# 5                Journal Emerging infectious diseases
# 6                          Journal BMC bioinformatics
# 7                         Journal Journal of Virology
# 8                                    Journal J. Virol
# 9           Source The Journal of Infectious Diseases
# 10  Journal Biosecurity and bioterrorism: biodefen...
# 11                             Journal PLoS Pathogens
# 12                                   Journal PloS one
# 13                                           Volume 4
# 14                               Journal EMBO reports
# 15  Publisher DIR, ECBC, ATTN: RDCB-XXX APG United...
# 16                         Source Journal of Virology
# 17         Journal The Journal of Infectious Diseases
# 18              Institution LOYOLA UNIVERSITY CHICAGO
#
#                                          descriptions citations
# 0   Coronaviruses encode papain-like proteases (PL...       219
# 1   Severe acute respiratory syndrome coronavirus ...       189
# 2   The MinION™ nanopore sequencer was recently re...       179
# 3   Middle East respiratory syndrome coronavirus (...       135
# 4   To combat the public health threat from emergi...        70
# 5   Nanopore sequencing, a novel genomics technolo...        39
# 6   The detection of pathogens in complex sample b...        23
# 7   Recent advances in mass spectrometry methods a...        17
# 8   Middle East Respiratory Syndrome coronavirus (...        17
# 9   The ongoing moratorium on gain-of-function (GO...        16
# 10  Increasing threats of bioterrorism and the eme...        14
# 11  The current Ebola virus outbreak has highlight...        10
# 12  While overall rates of meningococcal disease h...         8
# 13                                                            4
# 14  There is ongoing discussion among the scientif...         3
# 15  Over the past five years, research and develop...         2
# 16  Undergraduate, graduate, and postdoctoral scie...         2
# 17  T o the E ditor—We appreciate Lipsitch's thoug...
# 18  Coronaviruses are important human pathogens an...

# %%
#name list
# driver = webdriver.Chrome(executable_path='C:\\chromedriver.exe')
driver = webdriver.Chrome(ChromeDriverManager().install())

# driver.get(personURL)
driver.get("https://scholar.google.com/citations?hl=en&user=t33F2BcAAAAJ")
button = driver.find_element(By.XPATH,"//button[@id='gsc_bpf_more']")

while True:
    if not button.is_enabled():
        break
    button.click()
    time.sleep(random.uniform(0.15, 1))
    
text = driver.page_source
soup = BeautifulSoup(text, 'html.parser')

objects = soup.find_all('tr', {"class": "gsc_a_tr"})

titles=[]
links=[]
for obj in objects:
    combined = str(obj.find_all('a', {"class": "gsc_a_at"}))[27:-5]
    titles.append(combined[combined.find('"')+2:])
    links.append('https://scholar.google.com' + combined[:combined.find('"')].replace('&amp;', '&').replace('&oe=ASCII', ''))

pubs = pd.DataFrame()
pubs['titles'] = titles
pubs['links'] = links

pubs[['descriptions', 'URL']] = ''

headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9'}

for i in range(len(pubs)):
    time.sleep(random.uniform(1, 2))
    text = requests.get(pubs.links[i], headers=headers).text
    soup = BeautifulSoup(text, 'html.parser')
    if soup.find_all('div', {"class": "gsh_csp"}):
        pubs.loc[i, 'descriptions'] = soup.find_all('div', {"class": "gsh_csp"})[0].text
    elif soup.find_all('div', {"class": "gsh_small"}):
        pubs.loc[i, 'descriptions'] = soup.find_all('div', {"class": "gsh_small"})[0].text
    if soup.find_all('a', {"class": "gsc_oci_title_link"}):
        pubs.loc[i, 'URL'] = soup.find_all('a', {"class": "gsc_oci_title_link"})[0].get('href')
    else:
        pubs.loc[i, 'URL'] = ' '
    
    

driver.close()    
pubs
# Out:
# C:\Users\Simon\AppData\Local\Temp\ipykernel_20540\1062606325.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
#                                                titles  \
# 0   MERS-CoV papain-like protease has deISGylating...
# 1   Structural basis for the ubiquitin-linkage spe...
# 2   Bacterial and viral identification and differe...
# 3   Assessing activity and inhibition of Middle Ea...
# 4   Cell-based antiviral screening against coronav...
# 5   Use of unamplified RNA/cDNA–hybrid nanopore se...
# 6   Pathosphere. org: pathogen detection and chara...
# 7   Comparative characterization of the Sindbis vi...
# 8   Assessing activity and inhibition of MERS-CoV ...
# 9   Gain-of-function research and the relevance to...
# 10  The planning, execution, and evaluation of a m...
# 11  Effectively communicating the uncertainties su...
# 12  Tracking a serial killer: Integrating phylogen...
# 13  440 Rosenzweig CN, Minot SS: Bacterial and vir...
# 14  When gain‐of‐function research is not “gain‐of...
# 15  Assessment of wearable technology for integrat...
# 16  Careers in virology: public health opportuniti...
# 17                                  Reply to Lipsitch
# 18  Coronavirus proteases as therapeutic targets: ...
#
#                                                 links descriptions URL
# 0   https://scholar.google.com/citations?view_op=v...
# 1   https://scholar.google.com/citations?view_op=v...
# 2   https://scholar.google.com/citations?view_op=v...
# 3   https://scholar.google.com/citations?view_op=v...
# 4   https://scholar.google.com/citations?view_op=v...
# 5   https://scholar.google.com/citations?view_op=v...
# 6   https://scholar.google.com/citations?view_op=v...
# 7   https://scholar.google.com/citations?view_op=v...
# 8   https://scholar.google.com/citations?view_op=v...
# 9   https://scholar.google.com/citations?view_op=v...
# 10  https://scholar.google.com/citations?view_op=v...
# 11  https://scholar.google.com/citations?view_op=v...
# 12  https://scholar.google.com/citations?view_op=v...
# 13  https://scholar.google.com/citations?view_op=v...
# 14  https://scholar.google.com/citations?view_op=v...
# 15  https://scholar.google.com/citations?view_op=v...
# 16  https://scholar.google.com/citations?view_op=v...
# 17  https://scholar.google.com/citations?view_op=v...
# 18  https://scholar.google.com/citations?view_op=v...

# %%
driver.close()
